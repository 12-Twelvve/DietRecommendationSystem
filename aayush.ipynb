# %%
import pandas as pd
import numpy as np

# %%
food_df=pd.read_csv('food.csv')
food_df2=pd.read_csv('food_all.csv')
df=food_df
df2=food_df2

# %%
df.head()
df.shape
# Out:
# (89, 16)

# %%
df2.head()
print(df2.shape)
# Out:
# (7413, 48)

# %%
df2.head()
# Out:
#      Category               Description  Nutrient Data Bank Number  \
# 0      BUTTER          BUTTER,WITH SALT                       1001
# 1      BUTTER  BUTTER,WHIPPED,WITH SALT                       1002
# 2  BUTTER OIL      BUTTER OIL,ANHYDROUS                       1003
# 3      CHEESE               CHEESE,BLUE                       1004
# 4      CHEESE              CHEESE,BRICK                       1005
#
#    Data.Alpha Carotene  Data.Ash  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 0                    0      2.11                 158                        0
# 1                    0      2.11                 158                        0
# 2                    0      0.00                 193                        0
# 3                    0      5.11                  74                        0
# 4                    0      3.18                  76                        0
#
#    Data.Carbohydrate  Data.Cholesterol  Data.Choline  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_items     89 non-null     object
#  1   Breakfast      89 non-null     int64
#  2   Lunch          89 non-null     int64
#  3   Dinner         89 non-null     int64
#  4   VegNovVeg      89 non-null     object
#  5   Calories       89 non-null     int64
#  6   Fats           89 non-null     float64
#  7   Proteins       89 non-null     float64
#  8   Iron           89 non-null     float64
#  9   Calcium        89 non-null     float64
#  10  Sodium         89 non-null     int64
#  11  Potassium      89 non-null     float64
#  12  Carbohydrates  89 non-null     float64
#  13  Fibre          89 non-null     float64
#  14  VitaminD       89 non-null     int64
#  15  Sugars         89 non-null     float64
# dtypes: float64(8), int64(6), object(2)
# memory usage: 11.2+ KB

# %%
print(f'Categorical Features:   {len([_d for _d in df.columns if df[_d].dtype == object])}')
print(f'Numerical Features: {len([_d for _d in df.columns if df[_d].dtype == int])}')
# Out:
# Categorical Features:   2
# Numerical Features: 6

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7413 entries, 0 to 7412
# Data columns (total 48 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Category                                                 7413 non-null   object
#  1   Description                                              7413 non-null   object
#  2   Nutrient Data Bank Number                                7413 non-null   int64
#  3   Data.Alpha Carotene                                      7413 non-null   int64
#  4   Data.Ash                                                 7413 non-null   float64
#  5   Data.Beta Carotene                                       7413 non-null   int64
#  6   Data.Beta Cryptoxanthin                                  7413 non-null   int64
#  7   Data.Carbohydrate                                        7413 non-null   float64
# ...

# %%
df.describe(include=[np.number])
# Out:
#        Breakfast      Lunch     Dinner    Calories       Fats   Proteins  \
# count  89.000000  89.000000  89.000000   89.000000  89.000000  89.000000
# mean    0.471910   0.505618   0.685393  210.314607   8.577528   8.569663
# std     0.502039   0.502801   0.466990  155.350893  11.383888   8.841861
# min     0.000000   0.000000   0.000000    1.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   89.000000   0.400000   2.300000
# 50%     0.000000   1.000000   1.000000  184.000000   3.700000   4.500000
# 75%     1.000000   1.000000   1.000000  318.000000  12.000000  13.000000
# max     1.000000   1.000000   1.000000  579.000000  50.000000  46.000000
#
#             Iron     Calcium       Sodium    Potassium  Carbohydrates  \
# count  89.000000   89.000000    89.000000    89.000000      89.000000
# mean    3.709888   64.503371   250.887640   247.803371      26.473034
# std     8.554230  112.045798   323.154074   194.792561      25.051777
# ...

# %%
df.head()
# Out:
#              Food_items  Breakfast  Lunch  Dinner VegNovVeg  Calories  Fats  \
# 0      Asparagus Cooked          0      1       1                  22   0.2
# 1              Avocados          1      0       0         0       160  15.0
# 2               Bananas          1      0       0         0        89   0.3
# 3  Bagels made in wheat          0      1       1         0       250   1.5
# 4               Berries          1      0       0         0       349   0.4
#
#    Proteins  Iron  Calcium  Sodium  Potassium  Carbohydrates  Fibre  VitaminD  \
# 0       2.4  0.91     23.0      14      224.0            4.1    2.0         0
# 1       2.0  0.55     12.0       7      485.0            8.5    6.7         0
# 2       1.1  0.26      5.0       1      358.0           23.0    2.6         0
# 3      10.0  2.76     20.0     439      165.0           49.0    4.1         0
# 4      14.0  6.80    190.0     298       77.0           77.0   13.0         0
#
#    Sugars
# 0     1.3
# 1     0.7
# ...

# %%
data = df.iloc[:, [0] + list(range(5, df.shape[1]))]

# %%
data.head()
# Out:
#              Food_items  Calories  Fats  Proteins  Iron  Calcium  Sodium  \
# 0      Asparagus Cooked        22   0.2       2.4  0.91     23.0      14
# 1              Avocados       160  15.0       2.0  0.55     12.0       7
# 2               Bananas        89   0.3       1.1  0.26      5.0       1
# 3  Bagels made in wheat       250   1.5      10.0  2.76     20.0     439
# 4               Berries       349   0.4      14.0  6.80    190.0     298
#
#    Potassium  Carbohydrates  Fibre  VitaminD  Sugars
# 0      224.0            4.1    2.0         0     1.3
# 1      485.0            8.5    6.7         0     0.7
# 2      358.0           23.0    2.6         0    12.0
# 3      165.0           49.0    4.1         0     6.1
# 4       77.0           77.0   13.0         0    46.0

# %%
data.describe()
# Out:
#          Calories       Fats   Proteins       Iron     Calcium       Sodium  \
# count   89.000000  89.000000  89.000000  89.000000   89.000000    89.000000
# mean   210.314607   8.577528   8.569663   3.709888   64.503371   250.887640
# std    155.350893  11.383888   8.841861   8.554230  112.045798   323.154074
# min      1.000000   0.000000   0.000000   0.020000    0.000000     0.000000
# 25%     89.000000   0.400000   2.300000   0.500000    8.300000     7.000000
# 50%    184.000000   3.700000   4.500000   1.180000   18.000000    80.000000
# 75%    318.000000  12.000000  13.000000   2.780000   63.000000   381.000000
# max    579.000000  50.000000  46.000000  57.000000  631.000000  1531.000000
#
#          Potassium  Carbohydrates      Fibre    VitaminD     Sugars
# count    89.000000      89.000000  89.000000   89.000000  89.000000
# mean    247.803371      26.473034   2.997753   11.516854   8.005056
# std     194.792561      25.051777   5.037179   59.071819  16.444337
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (15,12))
ax = fig.gca()
data.select_dtypes(include=np.number).hist(ax =ax)
plt.show()
# Out:
# /tmp/ipykernel_74843/3575550645.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.select_dtypes(include=np.number).hist(ax =ax)

# %%
mpl.rcParams['figure.figsize'] = 10, 8
import seaborn as sns
sns.heatmap(data.select_dtypes(include=np.number).corr(), 
            vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(220, 20, n=200))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(3,4))
for category in data.select_dtypes(include='O'):
  data[category].value_counts().plot(kind='bar')
  plt.show()

# %%
data.isna().mean(axis=1).sum()
# Out:
# 0.0

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 30, 10

# %%
data.select_dtypes(include=np.number).boxplot()
# Out:
# <AxesSubplot:>

# %%
mpl.rcParams['figure.figsize'] = 15, 8
sns.countplot(x = 'Calories', data=df)
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='count'>
